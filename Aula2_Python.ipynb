# %% [markdown]
# Atividade 1

# %%
Nome = "Tiringa Fi da Peste"
Idade = 65
Profissao = "Desenvolvedor"
print("Seu nome é:", Nome)
print("Sua idade é:", Idade)
print("Sua profissão é:", Profissao)
# Out:
# Seu nome é: Tiringa Fi da Peste
# Sua idade é: 65
# Sua profissão é: Desenvolvedor

# %% [markdown]
# Atividade 2

# %%
n1 = 1
n2 = 2

soma = n1 + n2
mult = n1 * n2
div = n1 / n2
sub = n1 - n2
potenciacao = n1 ** n2
print("SOMA:",soma,"\n","Multiplicação:", mult,"\n", "Divisão:",div,"\n", "Subtração:", sub, "\n", "Potenciação:",potencicao )

# %% [markdown]
# Atividade 3
